# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np

data = {i :np.random.randn() for i in range(7)}
data
# Out:
# {0: 0.4371625773803723,
#  1: -0.49079774097348444,
#  2: -0.1342226898024832,
#  3: 1.2802753155855813,
#  4: 0.5864162591826632,
#  5: 0.8323144999773324,
#  6: 0.03033617268756224}

# %%
# %pwd
# Out:
# '/content'

# %%
# %run

# %% [markdown]
# # IPython과 주피터 노트북

# %% [markdown]
# *탭 자동완성 기능

# %%
an_apple = 27

# %%
an_example = 42

# %%
b = [1,2,3]

# %%
b.

# %%
import datetime

# %%
def func_with_keywords(ab=1, abb=2, abbb=3) :
  return a,b,c

# %%
func_with_keywords(ab)

# %%
b=[1,2,3] #list

# %%
def add_numbers(a,b):
  """
  Add two numbers together
  Returns
  -------
  the_sum : type of arguments
  return a + b
  """
  return a + b

# %%
add_numbers(1,2)
# Out:
# 3

# %%
add_numbers?

# %%
add_numbers??

# %% [markdown]
# %run 명령어

# %%
# !notepad ipython_script_test.py
# Out:
# /bin/bash: notepad: command not found

# %%
# %run test.py

# %%
a
# Out:
# 5

# %%
b
# Out:
# 6

# %%
c
# Out:
# 7.5

# %%
result
# Out:
# 1.4666666666666666

# %% [markdown]
# * %load 명령어

# %%
# %load test.py

# %%
print('hello') ; print('world') #연결
# Out:
# hello
# world

# %%
a = 5

# %%
if a == 10 :
    print('10입니다')
    print('10입니다2')
    
print('a가 아니어도 출력됩니다')
# Out:
# a가 아니어도 출력됩니다

# %%
import numpy as np

# %%
a = np.random.randn(100,100)

# %%
a
# Out:
# array([[ 1.27043893, -0.20993152,  2.56769314, ...,  0.24677544,
#         -0.94780435,  0.79094391],
#        [-2.77711874, -0.95648274, -1.12650336, ...,  0.01649935,
#         -1.54386179,  1.49315121],
#        [-0.56716001,  0.79761195,  0.0425176 , ..., -0.10870425,
#         -0.67599333,  0.32705611],
#        ...,
#        [-0.40194726,  0.18736922,  0.21085945, ...,  0.50041941,
#          0.98982678, -0.53160203],
#        [-0.15456425,  0.49663578, -0.74816973, ...,  0.44335975,
#          0.05699365, -0.65486696],
#        [ 0.99244479,  1.373586  ,  0.58442233, ..., -0.90878588,
#          0.20905447,  1.39838068]])

# %%
# %timeit np.dot(a,a)
# Out:
# The slowest run took 39.67 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 5: 104 µs per loop

# %%
foo = %pwd

# %%
foo
# Out:
# '/content'

# %%
# %magic

# %% [markdown]
# *matplotlib 통합

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
np.random.randn(50).cumsum()
# Out:
# array([1.517385  , 0.48830235, 0.19604356, 1.08616332, 2.43080138,
#        2.78671864, 2.18253554, 2.56593906, 1.09813879, 2.10333435,
#        2.88064029, 1.93982332, 2.74892664, 3.25648912, 4.51655287,
#        4.39804303, 4.95268815, 5.89860934, 5.04908041, 4.68249924,
#        5.53405176, 6.31960612, 5.59070483, 5.42964263, 6.31801602,
#        6.59059005, 7.89245387, 7.70470118, 9.3216039 , 8.65472202,
#        8.51517008, 6.94166642, 6.25205106, 5.7211697 , 3.87569346,
#        3.71032523, 6.6039076 , 6.45774756, 5.22132214, 6.97591211,
#        6.5990386 , 6.96565003, 6.52553157, 5.13471849, 4.43645983,
#        6.27014984, 5.60318202, 4.90182501, 3.46802624, 3.65581288])

# %%
plt.plot(np.random.randn(50).cumsum())

# %%
25*25
# Out:
# 625

# %%
5//2 #몫
# Out:
# 2

# %%
5 % 2 #나머지
# Out:
# 1

# %%
2 ** 10 #거듭제곱
# Out:
# 1024

# %%
int(5/2)
# Out:
# 2

# %%
int('10')
# Out:
# 10

# %%
type(10)
# Out:
# int

# %%
type('hi')
# Out:
# str

# %%
divmod(5,2) #몫과 나머지 한번에 구하기
# Out:
# (2, 1)

# %%
4.3 - 2.7  # 1.6으로 한번에 떨어지지 않음
# Out:
# 1.5999999999999996

# %%
1.5 *3.1
# Out:
# 4.65

# %%
5.5 / 3.1
# Out:
# 1.7741935483870968

# %%
float(5)  #실수 만들기
# Out:
# 5.0

# %%
int(5.5)
# Out:
# 5

# %% [markdown]
# 아파트 소음 가장 심한 층수 출력
# 소음 가장 심한층 0.2476 * 도로와의 거리 + 4.159
# 소음이 가장 심한 층수 출력 (정수로) 거리 12

# %%
int(12 *0.2467 +4.159)
# Out:
# 7

# %% [markdown]
# * 수학모듈 math 를 이용하여 근의 공식 구하기
# * 근의 공식 이용하여 x**2 + x-2의 해 구하기

# %%
from math import sqrt

# %%
a = 1.0; b= 1.0; c=-2.0

x1= (-b + sqrt(b**2 - 4*a*c)) / (2*a)
x2 = (-b - sqrt(b**2 - 4*a*c)) / (2*a)

x1, x2
# Out:
# (1.0, -2.0)

# %%
x,y = 10,20
x,y = y,x
x,y
# Out:
# (20, 10)

# %%
del x #변수 삭제
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-689fb75dcf44> in <module>()
# ----> 1 del x #변수 삭제
#       2 x
#
# NameError: name 'x' is not defined

# %%
x = None #아무것도 출력 안되게
x

# %%
a = a+20  #변수대입 단순화
a += 20
a -= 2
a *= 3

# %%
x = input()
# Out:
# 1

# %%
x
# Out:
# '1'

# %%
x = input('문자열을 입력하세요')
# Out:
# 문자열을 입력하세요hello

# %%
a = input('첫번째 숫자를 입력하세요')
b = input('두번째 숫자를 입력하세요')
# Out:
# 첫번째 숫자를 입력하세요10
# 두번째 숫자를 입력하세요20

# %%
a+b
# Out:
# '1020'

# %%
a,b
# Out:
# ('10', '20')

# %%
int(a) + int(b)
# Out:
# 30

# %%
s = 'test1 test2'

# %%
s.split(' ')
# Out:
# ['test1', 'test2']

# %%
a, b = input('문자열을 입력하세요').split()
# Out:
# 문자열을 입력하세요python world

# %%
a
# Out:
# 'python'

# %%
b
# Out:
# 'world'

# %%
a,b = input('숫자를 입력하세요').split()
# Out:
# 숫자를 입력하세요10 20

# %%
a, b
# Out:
# ('10', '20')

# %%
a = int(a)

# %%
b = int(b)

# %%
a,b = map(int, input('숫자를 입력하세요').split(','))
# Out:
# 숫자를 입력하세요10,20

# %%
a,b
# Out:
# (10, 20)

# %%
a, b, c = map(int, input().split())
# Out:
# -10 20 30

# %%
국어 , 영어, 수학, 과학 = map(int, input().split())
mean = (국어 + 영어 + 수학 + 과학) / 4
print(mean)
# Out:
# 90 80 30 50
# 62.5

# %%
print('Hello','Python', sep='', end=',')
# Out:
# HelloPython,

# %%
print(1,2,3, sep='\n')
# Out:
# 1
# 2
# 3

# %%
print(1,2,3, sep='\t')
# Out:
# 1	2	3

# %%
print('\\')
# Out:
# \

# %%
print('Hello','\n','Python',sep='')
# Out:
# Hello
# Python

# %%
year = 2000
month = 10
day = 27
hour = 11
minute = 43
second = 59

print(year, month, day, sep="/", end=" ")
print(hour, minute, second, sep=":")
# Out:
# 2000/10/27 11:43:59
